# %%
import itertools
import random

# %matplotlib inline
import networkx as nx

# %%
import networkx as nx
import random

G = nx.Graph()
m = 2
initial_nodes = [0, 1]
G.add_nodes_from(initial_nodes)
G.add_edge(0, 1)

for new in range(10000):
    G.add_node(new)
    edge = list(G.edges)
    G.add_edge(new,random.choice(random.choice(edge)))

# %%
nx.draw(G)
print('Graph has', G.number_of_edges(), 'edges.')
print(G.edges)
# Out:
# /Users/tianshuo/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):
# Graph has 10000 edges.
# ...

# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate
import seaborn as sns
import matplotlib.pyplot as plt

# %%
list_degee=list(G.degree)

# %%
list1 = list(list_degee)

# %%
b = [i[1] for i in list1] 
b
# Out:
# [217,
#  130,
#  48,
#  41,
#  6,
#  26,
#  17,
#  25,
#  23,
#  3,
#  48,
#  25,
#  91,
#  11,
#  20,
#  21,
#  49,
#  38,
#  8,
#  33,
#  28,
#  15,
#  5,
#  21,
#  121,
#  22,
#  9,
#  2,
#  33,
#  5,
#  22,
#  40,
#  1,
#  2,
#  15,
#  38,
#  1,
#  21,
#  15,
#  7,
#  4,
#  2,
#  24,
#  2,
#  5,
#  49,
#  13,
#  58,
#  5,
#  14,
#  11,
#  9,
#  11,
#  5,
#  3,
#  9,
#  1,
#  7,
#  6,
#  4,
#  33,
#  41,
#  5,
#  8,
#  33,
#  3,
#  2,
#  7,
#  7,
#  1,
#  3,
#  4,
#  3,
#  29,
#  5,
#  28,
#  8,
#  12,
#  23,
#  4,
#  1,
#  3,
#  7,
#  11,
#  2,
#  6,
#  6,
#  1,
#  1,
#  15,
#  12,
#  6,
#  1,
#  2,
#  4,
#  34,
#  10,
#  5,
#  3,
#  12,
#  10,
#  2,
#  11,
#  1,
#  7,
#  7,
#  18,
#  4,
#  27,
#  8,
#  2,
#  4,
#  5,
#  4,
#  47,
#  7,
#  42,
#  2,
#  15,
#  2,
#  9,
#  4,
#  5,
#  4,
#  3,
#  34,
#  2,
#  7,
#  3,
#  11,
#  3,
#  21,
#  3,
#  27,
#  9,
#  1,
#  3,
#  8,
#  7,
#  10,
#  8,
#  3,
#  11,
#  10,
#  15,
#  4,
#  16,
#  10,
#  2,
#  8,
#  1,
#  4,
#  22,
#  3,
#  8,
# ...

# %%
list_x =[]
for i in range(1,250):
    list_x.append(i)

# %%
list_y =[]
for i in range(1,250):
    list_y.append(0)

# %%
list_z =[]
for i in range(1,250):
    list_z.append(math.sqrt(1/i)*0.664)

# %%
for i in b:
    list_y[i]=list_y[i]+1

# %%
del list_y[0]
del list_x[0]
del list_z[0]
len(list_y)
# Out:
# 248

# %%
for i in range(1,len(list_y)):
    list_y[i]=list_y[i]/len(list_y)

# %%
len(list_x)
# Out:
# 248

# %%
import math

# %%
    plt.figure(num=1, figsize=(8, 6))
    plt.title('Plot 1', size=14)
    plt.loglog(list_x,list_y,)
    plt.loglog(list_x,list_z,)
    plt.legend(loc='upper left')
# Out:
# No handles with labels found to put in legend.
